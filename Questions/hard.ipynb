# %%
# list

#Question: Write a program to rotate a list to the right by one position.

numbers=[1,2,3,4]
print(numbers[-1])
print(numbers[:-1])
print([numbers[-1]]+numbers[:-1])
# Out:
# 4
# [1, 2, 3]
# [4, 1, 2, 3]

# %%
# tuple

#Question: Write a program to count how many times a specific value appears in a tuple.

numbers=(1,2,3,4,5,2,1,2,2,1,1,1,1)
print(numbers.count(1))
print(numbers.count(2))
# Out:
# 6
# 4

# %%
# set

#Question: Given a list with repeated values, write a program to check if all elements are unique.

numbers=[1,2,3,4,5,2,1,2,2,1,1,1,1]
u_numbers=list(set(numbers))
if len(numbers)==len(set(numbers)):
    print("all elements are unique")
else:
    print("elements are not unique")
# Out:
# elements are not unique

# %%
# dictionary

#Question: Write a program to merge two dictionaries into one.

a={"binal":90, "bhoomi":95}
b={"riya":70, "khushi":80}
print({**a,**b})

#or
a.update(b)
print(a)
# Out:
# {'binal': 90, 'bhoomi': 95, 'riya': 70, 'khushi': 80}
# {'binal': 90, 'bhoomi': 95, 'riya': 70, 'khushi': 80}

# %%
# Real-World Problem

#Question: Write a program to store product names and prices in a dictionary and find the most expensive product.

products={"laptop":70000,"tv":50000,"fridge":180000,"machine":60000}
print(max(products,key=products.get),max(products.values()))

#or
most_expensive = max(products, key=products.get)
price = products[most_expensive]
print(f"The most expensive product is {most_expensive} with price {price}")
# Out:
# fridge 180000
# The most expensive product is fridge with price 180000
